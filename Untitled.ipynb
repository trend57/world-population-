# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('world_population.csv')
df.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
##top ten in world in 1970

df.sort_values(by='1970 Population', ascending=False, inplace=True)

# %%
#create a subset of the top ten in 1970
top_10 = df.head(10)

# %%
top_10
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 171     9  RUS            Russia            Moscow         Europe
# 93      4  IDN         Indonesia           Jakarta           Asia
# 102    11  JPN             Japan             Tokyo           Asia
# 27      7  BRA            Brazil          Brasilia  South America
# 74     19  DEU           Germany            Berlin         Europe
# 16      8  BGD        Bangladesh             Dhaka           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# ...

# %%
df.sort_values(by='1980 Population', ascending=False, inplace=True)

# %%
top_10 = df.head(10)
top_10.plot.bar('Country/Territory','1970 Population')
plt.savefig('bar1970.pdf', format='pdf')

top_10
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 171     9  RUS            Russia            Moscow         Europe
# 93      4  IDN         Indonesia           Jakarta           Asia
# 102    11  JPN             Japan             Tokyo           Asia
# 27      7  BRA            Brazil          Brasilia  South America
# 74     19  DEU           Germany            Berlin         Europe
# 16      8  BGD        Bangladesh             Dhaka           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# ...

# %%
top_10.plot.bar('Country/Territory','1980 Population')
plt.savefig('line_plot.pdf', format='pdf')

# %%
df.sort_values(by='1990 Population', ascending=False, inplace=True)
top_10 = df.head(10)
top_10
top_10.plot.bar('Country/Territory','1990 Population')
# Out:
# <AxesSubplot:xlabel='Country/Territory'>

# %%
df.sort_values(by='2000 Population', ascending=False, inplace=True)
top_10 = df.head(10)
top_10
top_10.plot.bar('Country/Territory','2000 Population')
plt.savefig('bar2000.pdf', format='pdf')

# %%
df.sort_values(by='2010 Population', ascending=False, inplace=True)
top_10 = df.head(10)
top_10
top_10.plot.bar('Country/Territory','2010 Population')
plt.savefig('bar2010.pdf', format='pdf')

# %% [markdown]
# ## df.sort_values(by='2020 Population', ascending=False, inplace=True)
# top_10 = df.head(10)
# top_10
# top_10.plot.bar('Country/Territory','2020 Population')
# plt.savefig('bar.pdf', format='pdf')

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
df.sort_values(by='Growth Rate', ascending=False, inplace=True)
top_10 = df.head(10)
top_10
top_10.plot.bar('Country/Territory','1970 Population')
plt.savefig('bargrowth1970.pdf', format='pdf')

# %%
df.sort_values(by='Growth Rate', ascending=False, inplace=True)
top_10 = df.head(10)
top_10
top_10.plot.bar('Country/Territory','1980 Population')
plt.savefig('bargrowth1980.pdf', format='pdf')

# %%
df.sort_values(by='Growth Rate', ascending=False, inplace=True)
top_10 = df.head(10)
top_10
top_10.plot.bar('Country/Territory','1990 Population')
plt.savefig('bargrowth1990.pdf', format='pdf')

# %%
df.sort_values(by='Growth Rate', ascending=False, inplace=True)
top_10 = df.head(10)
top_10
top_10.plot.bar('Country/Territory','2000 Population')
plt.savefig('bargrowth2000.pdf', format='pdf')

# %%
df.sort_values(by='Growth Rate', ascending=False, inplace=True)
top_10 = df.head(10)

top_10.plot.bar('Country/Territory','2010 Population')
plt.savefig('bargrowth2010.pdf', format='pdf')

# %%
df.sort_values(by='Growth Rate', ascending=False, inplace=True)
top_10 = df.head(10)
top_10
top_10.plot.bar('Country/Territory','2020 Population')
plt.savefig('bargrowth2020.pdf', format='pdf')

# %%
top_10

# %%
#sepate acording to continents

african_countries = df[df["Continent"].str.contains("Africa", case=False, na=False)]
asia_countries =  df[df["Continent"].str.contains("Asia", case=False, na=False)] 
europe_countries =  df[df["Continent"].str.contains("europe", case=False, na=False)] 
North_America =  df[df["Continent"].str.contains("North America", case=False, na=False)] 
South_America =  df[df["Continent"].str.contains("South America", case=False, na=False)] 
Oceania_countries =  df[df["Continent"].str.contains("Oceania", case=False, na=False)]

# %%
african_countries
# Out:
# 7973413042

# %%
fig = plt.figure(figsize=(10, 6))


african_countries.plot(kind="bar", x="Country/Territory", y="1970 Population", figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='Country/Territory'>

# %%
fig = plt.figure(figsize=(10, 6))
african_countries.plot(kind="bar", x="Country/Territory", y="2022 Population", figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='Country/Territory'>

# %%
african_countries_pop = df["2022 Population"].sum()
african_countries_pop
# Out:
# 7973413042

# %%
fig = plt.figure(figsize=(10, 6))

europe_countries.plot(kind="bar", x="Country/Territory", y="1970 Population", figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='Country/Territory'>

# %%
european_pop = europe_countries["2022 Population"].sum()
european_pop
# Out:
# 743147538

# %%
fig = plt.figure(figsize=(10, 6))

asia_countries.plot(kind="bar", x="Country/Territory", y="1970 Population", figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='Country/Territory'>

# %%
asia_countries_pop = asia_countries["2022 Population"].sum()
asia_countries_pop
# Out:
# 4721383274
